# %%
from domino.data_sources import DataSourceClient
import os

# create a client and fetch the data source instance
client = DataSourceClient()
data_source = client.get_datasource("clinical_data_repository")

# specify the local directory to download files to
local_dir = "/mnt/data/test"

# download each file to the local directory
for obj in data_source.list_objects():
    key = obj.key
    print(key)
    local_path = os.path.join(local_dir, key)
    full_local_path = os.path.dirname(local_path)
    if not os.path.isdir(full_local_path):
        print(f"{full_local_path} directory doesn't exist... Creating it...")
        os.makedirs(full_local_path)
    print(f"Attempting to download {key} to {local_path}")
    data_source.download_file(key, local_path)
# Out:
# ae.xpt
# Attempting to download ae.xpt to /mnt/data/test/ae.xpt
# blankcrf.pdf
# Attempting to download blankcrf.pdf to /mnt/data/test/blankcrf.pdf
# cm.xpt
# Attempting to download cm.xpt to /mnt/data/test/cm.xpt
# datasets/adae.xpt
# /mnt/data/test/datasets directory doesn't exist... Creating it...
# Attempting to download datasets/adae.xpt to /mnt/data/test/datasets/adae.xpt
# datasets/adlbc.xpt
# Attempting to download datasets/adlbc.xpt to /mnt/data/test/datasets/adlbc.xpt
# datasets/adlbh.xpt
# Attempting to download datasets/adlbh.xpt to /mnt/data/test/datasets/adlbh.xpt
# datasets/adlbhy.xpt
# Attempting to download datasets/adlbhy.xpt to /mnt/data/test/datasets/adlbhy.xpt
# datasets/adqsadas.xpt
# Attempting to download datasets/adqsadas.xpt to /mnt/data/test/datasets/adqsadas.xpt
# datasets/adqscibc.xpt
# Attempting to download datasets/adqscibc.xpt to /mnt/data/test/datasets/adqscibc.xpt
# datasets/adqsnpix.xpt
# Attempting to download datasets/adqsnpix.xpt to /mnt/data/test/datasets/adqsnpix.xpt
# datasets/adsl.xpt
# Attempting to download datasets/adsl.xpt to /mnt/data/test/datasets/adsl.xpt
# datasets/adtte.xpt
# Attempting to download datasets/adtte.xpt to /mnt/data/test/datasets/adtte.xpt
# datasets/advs.xpt
# Attempting to download datasets/advs.xpt to /mnt/data/test/datasets/advs.xpt
# datasets/dataguide.pdf
# Attempting to download datasets/dataguide.pdf to /mnt/data/test/datasets/dataguide.pdf
# datasets/define-v1-updated-html.xsl
# Attempting to download datasets/define-v1-updated-html.xsl to /mnt/data/test/datasets/define-v1-updated-html.xsl
# datasets/define.pdf
# Attempting to download datasets/define.pdf to /mnt/data/test/datasets/define.pdf
# datasets/define.xml
# Attempting to download datasets/define.xml to /mnt/data/test/datasets/define.xml
# define-v1-updated-html.xsl
# Attempting to download define-v1-updated-html.xsl to /mnt/data/test/define-v1-updated-html.xsl
# define.pdf
# Attempting to download define.pdf to /mnt/data/test/define.pdf
# define.xml
# Attempting to download define.xml to /mnt/data/test/define.xml
# dm.xpt
# Attempting to download dm.xpt to /mnt/data/test/dm.xpt
# ds.xpt
# Attempting to download ds.xpt to /mnt/data/test/ds.xpt
# ex.xpt
# Attempting to download ex.xpt to /mnt/data/test/ex.xpt
# lb.xpt
# Attempting to download lb.xpt to /mnt/data/test/lb.xpt
# mh.xpt
# Attempting to download mh.xpt to /mnt/data/test/mh.xpt
# programs/adae.sas
# /mnt/data/test/programs directory doesn't exist... Creating it...
# Attempting to download programs/adae.sas to /mnt/data/test/programs/adae.sas
# programs/at14-5-02.sas
# Attempting to download programs/at14-5-02.sas to /mnt/data/test/programs/at14-5-02.sas
# qs.xpt
# Attempting to download qs.xpt to /mnt/data/test/qs.xpt
# relrec.xpt
# Attempting to download relrec.xpt to /mnt/data/test/relrec.xpt
# sc.xpt
# Attempting to download sc.xpt to /mnt/data/test/sc.xpt
# se.xpt
# Attempting to download se.xpt to /mnt/data/test/se.xpt
# suppae.xpt
# Attempting to download suppae.xpt to /mnt/data/test/suppae.xpt
# suppdm.xpt
# Attempting to download suppdm.xpt to /mnt/data/test/suppdm.xpt
# suppds.xpt
# Attempting to download suppds.xpt to /mnt/data/test/suppds.xpt
# supplb.xpt
# Attempting to download supplb.xpt to /mnt/data/test/supplb.xpt
# sv.xpt
# Attempting to download sv.xpt to /mnt/data/test/sv.xpt
# ta.xpt
# Attempting to download ta.xpt to /mnt/data/test/ta.xpt
# te.xpt
# Attempting to download te.xpt to /mnt/data/test/te.xpt
# ti.xpt
# Attempting to download ti.xpt to /mnt/data/test/ti.xpt
# ts.xpt
# Attempting to download ts.xpt to /mnt/data/test/ts.xpt
# tv.xpt
# Attempting to download tv.xpt to /mnt/data/test/tv.xpt
# vs.xpt
# Attempting to download vs.xpt to /mnt/data/test/vs.xpt
